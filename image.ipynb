# %% [markdown]
# | 阶段               | 核心操作                                   | 关键技术                                                                 | 创新特性                         |
# |--------------------|--------------------------------------------|--------------------------------------------------------------------------|----------------------------------|
# | **输入预处理**     | - 多尺度图像归一化<br>- 标签语义嵌入       | - 自适应直方图均衡<br>- Word2Vec标签编码                                | - 光照鲁棒性增强<br>- 标签语义空间构建 |
# | **双教师建模**     | - EfficientNet-B4特征提取<br>- ConvNeXt-Tiny时序建模 | - 深度可分离卷积<br>- 层级特征金字塔                                  | - 异构模型融合<br>- 多粒度特征交互    |
# | **动态蒸馏训练**   | - KL散度损失计算<br>- 梯度余弦对齐         | $\mathcal{L}_{KD} = \alpha T^2 \sum_{i=1}^2 D_{KL}(q_i \parallel p) + (1-\alpha)\mathcal{L}_{CE}$ | - 温度系数自适应<br>- 梯度方向约束 |
# | **鲁棒特征生成**   | - 高斯噪声注入<br>- 对抗样本增强           | $\tilde{x} = x + \epsilon \cdot sign(\nabla_x J(\theta,x,y))$           | - 特征空间正则化<br>- 决策边界平滑   |
# | **可解释评估**     | - 经济价值损失函数<br>- Pareto前沿分析     | $\mathcal{L}_{eco} = \sum_{c=1}^C v_c \cdot (1 - \frac{TP_c}{TP_c+FN_c})$ | - 作物价值加权<br>- 多目标优化       |
